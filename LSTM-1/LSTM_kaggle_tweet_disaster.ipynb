# %% [markdown]
# # Check DataSet

# %%
import pandas as pd
import numpy as np
import csv
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence
import re

# %%
data_train = pd.read_csv("train.csv")
data_test = pd.read_csv("test.csv")

# %%
data_train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %% [markdown]
# # import textaugment library.
# TextAugment is a Python 3 library for augmenting text for natural language processing applications. TextAugment stands on the giant shoulders of NLTK, Gensim, and TextBlob and plays nicely with them.

# %% [markdown]
# # Settings

# %%
#control the numer of words that can be passes to model
max_sequence_length = 30
#limit dictionary of words to 3000
max_words = 3000
#define the size of output vector from this layer for each word
embedding_size = 30
#once trained, the weights of LSTM neural network will be saved in a h5 file.
#so that you can reuse this model later
model_file = 'model.h5'
#store the word  dictionary and in the process of converting text to strings and backwoards
tokenizer_file = 'tokenizer.pickle'
#binary classification
num_classes = 2

# %% [markdown]
# # Text cleaning

# %%
def clean_str(string):
    #replace and simplify a lot of signals
    string = re.sub(r'http\S+', 'link', string) # replace links by generic text link
    string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)

    cleanr = re.compile('<.*?>')

    string = re.sub(r'\d+', '', string)
    string = re.sub(cleanr, '', string)
    string = re.sub("'", '', string)
    string = re.sub(r'\W+', ' ', string)
    string = string.replace('_', '')
    #turn to lower case
    return string.strip().lower()

# %%
cleaned_str = clean_str('Horrible Accident | Man Died In Wings of AirplaneåÊ(29-07-2015) http://t.co/wq3wJsgPHL')
cleaned_str
# Out:
# 'horrible accident man died in wings of airplane link'

# %% [markdown]
# # Remove stopwords

# %%
stop_words = set(stopwords.words('english'))
def remove_stopwords(word_list):
    no_stop_words = [w for w in word_list if not w in stop_words]
    return no_stop_words

# %%
remove_stopwords(cleaned_str.split(" "))
# Out:
# ['horrible', 'accident', 'man', 'died', 'wings', 'airplane', 'link']

# %% [markdown]
# # Data augmentation

# %%
#import and create an EDA example
from textaugment import EDA
t = EDA()
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %% [markdown]
# Random Deletion (RD): Randomly remove each word in the sentence with probability p.

# %%
for i in range(3):
    print(t.random_deletion('The pastor was not in the scene of the accident... who was the owner of the range rover?', p=0.2))
# Out:
# pastor was not in the scene of who was the of the range rover?
# The not in the scene of accident... who was the owner of the range
# The pastor was in the of the accident... who was the owner of the range rover?

# %% [markdown]
# Random Swap (RS): Randomly choose two words in the sentence and swap their positions. Do this n times.¶

# %%
for i in range(3):
    print(t.random_swap('The pastor was not in the scene of the accident... who was the owner of the range rover?'))
# Out:
# The pastor was not in the scene of the accident... who was range owner of the the rover?
# The the was not in the scene of the accident... who was the owner of pastor range rover?
# The pastor was not in the scene the the accident... who was of owner of the range rover?

# %% [markdown]
# Synonym Replacement (SR): Randomly choose n words from the sentence that are not stop words. Replace each of these words with one of its synonyms chosen at random.¶

# %%
for i in range(3):
    print(t.synonym_replacement('The pastor was not in the scene of the accident... who was the owner of the range rover?'))
# Out:
# The minister of religion was not in the scene of the accident... who was the owner of the range rover?
# The pastor was not in the scene of the accident... who was the owner of the mountain chain rover?
# The pastor was not in the scene of the accident... who was the owner of the tramp rover?

# %% [markdown]
# Random Insertion (RI): Find a random synonym of a random word in the sentence that is not a stop word. Insert that synonym into a random position in the sentence. Do this n times.

# %%
for i in range(3):
    print(t.random_insertion('The pastor was not in the scene of the accident... who was the owner of the range rover?'))
# Out:
# The pastor was not in the scene of the accident... who was possessor the owner of the range rover?
# The pastor was not in lay out the scene of the accident... who was the owner of the range rover?
# The pastor was not in the scene of the accident... who was the owner of the minister of religion range rover?

# %% [markdown]
# # Load dataset

# %%
data_train = data_train[['text', 'target']]

# %%
data_train
# Out:
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data_train.target)
plt.xlabel('Target')
plt.title('Number of disaster tweets')
# Out:
# Text(0.5, 1.0, 'Number of disaster tweets')

# %%
data_train['text'] = data_train['text'].apply(lambda x: clean_str(x))

sequences = []
targets = []

for index, row in data_train.iterrows():
    seqs = []
    text = row['text']

    # if empty text, skipping to next row data
    if not text:
        continue

    seqs.append(text)
    
    # apply data augmentation
    
    # random deletion
    seq2 = t.random_deletion(text, p=0.2)
    if type(seq2) == type([]):
        seqs.append(seq2[0])
    else:
        seqs.append(seq2)
        # random swap
    if len(text) > 1:
        seqs.append(t.random_swap(text))

    # synonym replacement and random insertion
    for i in range(2):
        seqs.append(t.synonym_replacement(text))    
        try:
            seqs.append(t.random_insertion(text))
        except:
            pass
    """
    All sequence variations created in the data augmentation process are grouped in bags. 
    This is important to avoid that in the process of splitting the data, variations of 
    the same sequence are allocated in different sets. For example, an X variation of 
    sequence A falls in the training set and an Y variation of sequence A falls in the test set.
    """
    sequence_group = []
    target_group = []

    target = row['target']

    for sequence in seqs: 
        word_list = text_to_word_sequence(sequence)
        
        # remove stop words
        no_stop_words = remove_stopwords(word_list)
        
        if not no_stop_words:
            continue

        sequence_group.append(" ".join(no_stop_words))
        target_group.append(target)

    sequences.append(sequence_group)
    targets.append(target_group)


X = sequences
Y = np.array(targets)

print("{bags_count} bags".format(bags_count=len(X)))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 7613 bags

# %%
X
# Out:
# [['deeds reason earthquake may allah forgive us',
#   'reason earthquake may allah forgive us',
#   'deeds reason earthquake may allah forgive us',
#   'act reason earthquake may allah forgive us',
#   'deeds reason title earthquake may allah forgive us',
#   'act reason earthquake may allah forgive us',
#   'deeds reason usa earthquake may allah forgive us'],
#  ['forest fire near la ronge sask canada',
#   'forest near la ronge sask canada',
#   'forest sask near la ronge fire canada',
#   'forest fire come la ronge sask canada',
#   'wood forest fire near la ronge sask canada',
#   'forest fire near pelican state ronge sask canada',
#   'forest fire near la ronge sask wood canada'],
#  ['residents asked shelter place notified officers evacuation shelter place orders expected',
#   'residents shelter place notified shelter place orders',
#   'residents asked shelter place notified officers evacuation shelter place orders expected',
#   'residents demand shelter place notified officers evacuation shelter place orders expected',
#   'residents asked shelter place notified officers site evacuation shelter place orders expected',
#   'residents asked shelter send notified officers evacuation shelter send orders expected',
#   'residents asked notify shelter place notified officers evacuation shelter place orders expected'],
#  ['people receive wildfires evacuation orders california',
#   'people receive wildfires evacuation orders california',
#   'people receive wildfires orders evacuation california',
#   'people receive wildfires voidance orders california',
#   'people receive wildfires evacuation find orders california',
#   'people receive wildfires evacuation ordinate california',
#   'people mass receive wildfires evacuation orders california'],
#  ['got sent photo ruby alaska smoke wildfires pours school',
#   'got sent photo ruby smoke pours',
#   'got sent photo alaska smoke wildfires pours ruby school',
#   'stick sent photo ruby alaska smoke wildfires pours school',
#   'got scarlet sent photo ruby alaska smoke wildfires pours school',
#   'got mail photo ruby alaska smoke wildfires pours school',
#   'got sent photo ruby alaska smoke last frontier wildfires pours school'],
#  ['rockyfire update california hwy closed directions due lake county fire cafire wildfires',
#   'rockyfire california hwy closed directions due lake county fire',
#   'rockyfire california hwy closed directions due update lake county fire cafire wildfires',
#   'rockyfire update california hwy closed centering due lake county fire cafire wildfires',
#   'rockyfire close update california hwy closed directions due lake county fire cafire wildfires',
#   'rockyfire update california hwy closed directions due lake county fire cafire wildfire',
#   'rockyfire update california hwy closed directions due ca lake county fire cafire wildfires'],
#  ['flood disaster heavy rain causes flash flooding streets manitou colorado springs areas',
#   'flood disaster rain causes flash flooding streets colorado',
#   'flood disaster heavy rain colorado flash flooding streets manitou causes springs areas',
#   'flood disaster heavy rain causes flash flooding street manitou colorado springs areas',
#   'flood disaster heavy causa rain causes flash flooding streets manitou colorado springs areas',
#   'flood disaster heavy rain causes flash flooding streets manitou co springs areas',
#   'flood disaster heavy rain causes flash flooding streets manitou colorado springs calamity areas'],
#  ['im top hill see fire woods',
#   'im top hill see fire woods',
#   'im top hill fire see woods',
#   'im top hill see fire sir henry joseph wood',
#   'im ensure top hill see fire woods',
#   'im top hill see provoke woods',
#   'forest im top hill see fire woods'],
#  ['emergency evacuation happening building across street',
#   'emergency happening across street',
#   'emergency happening evacuation building across street',
#   'emergency emptying happening building across street',
#   'emergency evacuation happening building across crosswise street',
#   'emergency evacuation encounter building across street',
#   'crosswise emergency evacuation happening building across street'],
#  ['im afraid tornado coming area',
#   'afraid tornado coming area',
#   'coming afraid tornado im area',
#   'im afraid tornado come area',
#   'im afraid tornado coming come area',
#   'im afraid tornado coming orbit',
#   'im afraid arena tornado coming area'],
#  ['three people died heat wave far',
#   'people died wave far',
#   'three people died heat wave far',
#   'three people died heat wave interahamwe',
#   'three people died heat former armed forces wave far',
#   'three people exit heat wave far',
#   'three people died heat wave far'],
#  ['haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding',
#   'haha south tampa getting flooded hah wait second south tampa gonna gonna fvck flooding',
#   'haha tampa getting flooded hah wait second live south tampa south gonna gonna fvck flooding',
#   'haha south tampa getting flooded hah wait second populate south tampa gonna gonna fvck flooding',
#   'haha south tampa getting hold flooded hah wait second live south tampa gonna gonna fvck flooding',
#   'haha south tampa getting flooded hah waitress second live south tampa gonna gonna fvck flooding',
#   'haha south tampa getting flooded hah wait second live incur south tampa gonna gonna fvck flooding'],
#  ['raining flooding florida tampabay tampa days lost count',
#   'raining tampabay days lost count',
#   'raining flooding florida tampabay lost days tampa count',
#   'raining glut florida tampabay tampa days lost count',
#   'raining disoriented flooding florida tampabay tampa days lost count',
#   'raining flooding florida tampabay tampa clarence shepard day jr lost count',
#   'raining flooding florida tampabay tampa days rain lost count'],
#  ['flood bago myanmar arrived bago',
#   'flood bago myanmar arrived bago',
#   'flood bago myanmar arrived bago',
#   'flood bago myanmar go far bago',
#   'flood bago flood lamp myanmar arrived bago',
#   'flood bago myanmar arrive bago',
#   'flood go far bago myanmar arrived bago'],
#  ['damage school bus multi car crash breaking',
#   'damage school bus car crash breaking',
#   'damage school crash multi car bus breaking',
#   'damage school bus multi car crash give away',
#   'damage school bus multi car cable car crash breaking',
#   'impairment school bus multi car crash breaking',
#   'damage school bus multi car crash coach breaking'],
#  ['man', 'man', 'man', 'gentleman', 'piece man', 'homo', 'piece man'],
#  ['love fruits',
#   'love fruits',
#   'fruits love',
#   'love fruit',
#   'love yield fruits',
#   'love yield',
#   'yield love fruits'],
#  ['summer lovely',
#   'summer',
#   'lovely summer',
#   'summer pin',
#   'pin summer lovely',
#   'summer pin',
#   'summer summertime lovely'],
#  ['car fast',
#   'fast',
#   'car fast',
#   'car degraded',
#   'car profligate fast',
#   'car riotous',
#   'car profligate fast'],
#  ['goooooooaaaaaal', 'goooooooaaaaaal', 'goooooooaaaaaal', 'goooooooaaaaaal'],
#  ['ridiculous',
#   'ridiculous',
#   'ridiculous',
#   'idiotic',
#   'cockeyed ridiculous',
#   'farcical',
#   'cockeyed ridiculous'],
#  ['london cool',
#   'london cool',
#   'london cool',
#   'london sang froid',
#   'assuredness london cool',
#   'london sang froid',
#   'london assuredness cool'],
#  ['love skiing',
#   'love',
#   'love skiing',
#   'go skiing',
#   'love ski skiing',
#   'love ski',
#   'eff love skiing'],
#  ['wonderful day',
#   'wonderful day',
#   'wonderful day',
#   'wonderful daylight',
#   'sidereal day wonderful day',
#   'wonderful mean solar day',
#   'wonderful sidereal day day'],
#  ['looooool', 'looooool', 'looooool', 'looooool', 'looooool'],
#  ['way ca nt eat shit',
#   'ca eat',
#   'shit way ca nt eat',
#   'way ca national trust eat shit',
#   'way ca nt run eat shit',
#   'direction ca nt eat shit',
#   'way right smart ca nt eat shit'],
#  ['nyc last week',
#   'nyc last',
#   'week last nyc',
#   'nyc last hebdomad',
#   'nyc workweek last week',
#   'nyc finish week',
#   'nyc last close week'],
#  ['love girlfriend',
#   'love girlfriend',
#   'love girlfriend',
#   'sexual love girlfriend',
#   'love eff girlfriend',
#   'love lady friend',
#   'love eff girlfriend'],
#  ['cooool', 'cooool', 'cooool', 'cooool', 'cooool'],
#  ['like pasta',
#   'like pasta',
#   'pasta like',
#   'like alimentary paste',
#   'like wish pasta',
#   'corresponding pasta',
#   'wish like pasta'],
#  ['end',
#   'end',
#   'end',
#   'conclusion',
#   'remainder end',
#   'closing',
#   'remainder end'],
#  ['bbcmtd wholesale markets ablaze link',
#   'bbcmtd wholesale markets ablaze link',
#   'link wholesale markets ablaze bbcmtd',
#   'bbcmtd wholesale commercialise ablaze link',
#   'linkup bbcmtd wholesale markets ablaze link',
#   'bbcmtd sweeping markets ablaze link',
#   'aflare bbcmtd wholesale markets ablaze link'],
#  ['always try bring heavy metal rt link',
#   'always bring heavy metal rt link',
#   'always try bring heavy metal rt link',
#   'always taste bring heavy metal rt link',
#   'always try taste bring heavy metal rt link',
#   'always try take heavy metal rt link',
#   'metallic always try bring heavy metal rt link'],
#  ['africanbaze breaking news nigeria flag set ablaze aba link',
#   'africanbaze breaking news nigeria flag ablaze aba link',
#   'africanbaze breaking nigeria news flag set ablaze aba link',
#   'africanbaze breaking news nigeria flag set fire aba link',
#   'africanbaze breaking news nigeria flag set ablaze aba federal republic nigeria link',
#   'africanbaze breaking news nigeria flagstone set ablaze aba link',
#   'africanbaze breaking news aflare nigeria flag set ablaze aba link'],
#  ['crying set ablaze',
#   'ablaze',
#   'crying set ablaze',
#   'crying correct ablaze',
#   'stage set crying set ablaze',
#   'crying readiness ablaze',
#   'crying set aflare ablaze'],
#  ['plus side look sky last night ablaze link',
#   'side look sky last night ablaze link',
#   'plus side look last night sky ablaze link',
#   'plus side look sky last nox ablaze link',
#   'plus side look depend sky last night ablaze link',
#   'plus side look toss last night ablaze link',
#   'plus side look sky last night close ablaze link'],
#  ['phdsquares mufc built much hype around new acquisitions doubt set epl ablaze season',
#   'phdsquares mufc built much hype around new acquisitions epl ablaze season',
#   'phdsquares mufc built much hype doubt new acquisitions around set epl ablaze season',
#   'phdsquares mufc construct much hype around new acquisitions doubt set epl ablaze season',
#   'phdsquares mufc built make much hype around new acquisitions doubt set epl ablaze season',
#   'phdsquares mufc built much hype around new acquisitions doubt set epl ablaze flavour',
#   'phdsquares stage set mufc built much hype around new acquisitions doubt set epl ablaze season'],
#  ['inec office abia set ablaze link',
#   'inec office abia set link',
#   'inec office link set ablaze abia',
#   'inec office abia fit ablaze link',
#   'inec office abia set ablaze stage set link',
#   'inec berth abia set ablaze link',
#   'inec office linkup abia set ablaze link'],
#  ['barbados bridgetown jamaica two cars set ablaze santa cruz head st elizabeth police superintende link',
#   'barbados bridgetown jamaica cars ablaze santa cruz head st elizabeth police superintende link',
#   'barbados bridgetown jamaica two cars set santa cruz head ablaze st elizabeth police superintende link',
#   'barbados bridgetown jamaica two cars set ablaze santa cruz head st elizabeth law superintende link',
#   'barbados bridgetown jamaica two cars set ablaze cable car santa cruz head st elizabeth police superintende link',
#   'barbados bridgetown jamaica ii cars set ablaze santa cruz head st elizabeth police superintende link',
#   'barbados bridgetown jamaica two cars set ablaze santa cruz st nick head st elizabeth police superintende link'],
#  ['ablaze lord',
#   'ablaze lord',
#   'ablaze lord',
#   'alight lord',
#   'ablaze lord aflare',
#   'alight lord',
#   'ablaze aflare lord'],
#  ['check link link link link nsfw',
#   'check link link link link nsfw',
#   'check link link link link nsfw',
#   'check join join join join nsfw',
#   'check linkup link link link link nsfw',
#   'match link link link link nsfw',
#   'linkup check link link link link nsfw'],
#  ['outside ablaze alive dead inside',
#   'outside ablaze alive inside',
#   'outside ablaze alive dead inside',
#   'outside aroused alive dead inside',
#   'outside remote ablaze alive dead inside',
#   'away ablaze alive dead inside',
#   'remote outside ablaze alive dead inside'],
#  ['awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care us',
#   'awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care us',
#   'awesome time visiting cfc care office ancop site ablaze thanks tita vida taking head us',
#   'amazing time visiting cfc head office ancop site ablaze thanks tita vida taking care us',
#   'awesome time visiting cfc head aflare office ancop site ablaze thanks tita vida taking care us',
#   'awesome time visiting cfc head office ancop site ablaze thank tita vida taking care us',
#   'awesome time impose visiting cfc head office ancop site ablaze thanks tita vida taking care us'],
#  ['soooo pumped ablaze southridgelife',
#   'pumped ablaze southridgelife',
#   'soooo pumped ablaze southridgelife',
#   'soooo pump ablaze southridgelife',
#   'soooo pumped pumped ablaze southridgelife',
#   'soooo pumped aflare southridgelife',
#   'soooo pumped pumped ablaze southridgelife'],
#  ['wanted set chicago ablaze preaching hotel link',
#   'wanted chicago ablaze preaching hotel link',
#   'hotel wanted set chicago ablaze preaching link',
#   'wanted set chicago ablaze discourse hotel link',
#   'wanted set chicago ablaze preaching windy city hotel link',
#   'cherished set chicago ablaze preaching hotel link',
#   'wanted preach set chicago ablaze preaching hotel link'],
#  ['gained followers last week know stats grow link',
#   'gained followers last week know stats grow link',
#   'gained followers last week know stats grow link',
#   'gained followers last week know stats grow colligate',
#   'gained followers last week close know stats grow link',
#   'gained followers last week know stats farm link',
#   'gained followers last close week know stats grow link'],
#  ['west burned thousands wildfires ablaze california alone link',
#   'west burned thousands wildfires ablaze california link',
#   'ablaze west burned thousands wildfires california alone link',
#   'west burned thousands wildfires ablaze ca alone link',
#   'west burned thousands wildfires ablaze westward california alone link',
#   'west burned thousands wildfires aroused california alone link',
#   'aflare west burned thousands wildfires ablaze california alone link'],
#  ['building perfect tracklist life leave streets ablaze',
#   'building perfect tracklist life leave streets ablaze',
#   'building life tracklist perfect leave streets ablaze',
#   'building gross tracklist life leave streets ablaze',
#   'building perfect parting tracklist life leave streets ablaze',
#   'building perfect tracklist life leave streets fire',
#   'building perfect tracklist life leave biography streets ablaze'],
#  ['check link link link link nsfw',
#   'link link link link nsfw',
#   'link link check link link nsfw',
#   'jibe link link link link nsfw',
#   'check linkup link link link link nsfw',
#   'control link link link link nsfw',
#   'check link link link linkup link nsfw'],
#  ['first night retainers quite weird better get used wear every single night next year least',
#   'first night retainers quite weird get wear every single night next year least',
#   'first night retainers wear quite weird better get used every single night next year least',
#   'first night retainers quite weird better get used wear every single night next year lowest degree',
#   'first night retainers quite weird better get used wear every single incur night next year least',
#   'first night retainers quite uncanny better get used wear every single night next year least',
#   'first night retainers quite weird better get used wear every single night next year nighttime least'],
#  ['deputies man shot brighton home set ablaze link',
#   'man brighton home set ablaze',
#   'deputies home shot brighton man set ablaze link',
#   'deputies man shot brighton rest home set ablaze link',
#   'deputies piece man shot brighton home set ablaze link',
#   'deputies humankind shot brighton home set ablaze link',
#   'deputies man shot brighton home set ablaze aflare link'],
#  ['man wife get six years jail setting ablaze niece link',
#   'wife get jail setting ablaze niece link',
#   'man wife link six years jail setting ablaze niece get',
#   'adult male wife get six years jail setting ablaze niece link',
#   'man wife get six years jail setting ablaze niece married woman link',
#   'man wife nonplus six years jail setting ablaze niece link',
#   'man married woman wife get six years jail setting ablaze niece link'],
#  ['santa cruz head st elizabeth police superintendent lanford salmon r link link',
#   'santa head st police superintendent salmon r link',
#   'link cruz head st elizabeth police superintendent lanford salmon r link santa',
#   'santa cruz head st elizabeth police superintendent lanford pinkish orange r link link',
#   'santa super cruz head st elizabeth police superintendent lanford salmon r link link',
#   'santa cruz head st elizabeth police superintendent lanford pink orange r link link',
#   'santa cruz head super st elizabeth police superintendent lanford salmon r link link'],
#  ['police arsonist deliberately set black church north carolina ablaze link',
#   'police arsonist set black church north carolina ablaze link',
#   'ablaze arsonist deliberately set black church north carolina police link',
#   'police arsonist deliberately set black christian church north carolina ablaze link',
#   'aflare police arsonist deliberately set black church north carolina ablaze link',
#   'police arsonist deliberately set dark church north carolina ablaze link',
#   'police arsonist deliberately set black church service church north carolina ablaze link'],
#  ['noches el bestia alexis sanchez happy see teammates training hard goodnight gunners link',
#   'noches el sanchez happy see teammates hard goodnight gunners link',
#   'noches el teammates alexis sanchez happy see bestia training hard goodnight gunners link',
#   'noches el bestia alexis sanchez happy see mate training hard goodnight gunners link',
#   'noches el bestia alexis sanchez happy see teammates training hard goodnight gunners taurus link',
#   'noches el bestia alexis sanchez happy see teammates training hard goodnight cannoneer link',
#   'noches el bestia alexis sanchez happy see teammates mate training hard goodnight gunners link'],
#  ['kurds trampling turkmen flag later set ablaze others vandalized offices turkmen front diyala link',
#   'kurds turkmen later set ablaze vandalized offices turkmen front diyala link',
#   'kurds trampling turkmen flag later set ablaze others turkmen offices vandalized front diyala link',
#   'kurds trampling turkmen flag later set ablaze others vandalise offices turkmen front diyala link',
#   'kurds trampling signal flag turkmen flag later set ablaze others vandalized offices turkmen front diyala link',
#   'kurds trampling turkmen flag later set ablaze others vandalized office staff turkmen front diyala link',
#   'kurds trampling aflare turkmen flag later set ablaze others vandalized offices turkmen front diyala link'],
#  ['truck ablaze r voortrekker ave outside tambo intl cargo section link',
#   'r voortrekker ave outside section link',
#   'truck ablaze r voortrekker ave outside link tambo intl cargo section',
#   'truck ablaze r voortrekker ave alfresco tambo intl cargo section link',
#   'truck ablaze r voortrekker ave outside tambo intl cargo section linkup link',
#   'truck ablaze r voortrekker ave outside tambo intl cargo section tie',
#   'truck ablaze r voortrekker shipment ave outside tambo intl cargo section link'],
#  ['set hearts ablaze every city gift every skyline like kiss upon lips link',
#   'set hearts ablaze every city gift skyline kiss upon link',
#   'set hearts ablaze every city gift every skyline like kiss upon lips link',
#   'set hearts ablaze every city gift every visible horizon like kiss upon lips link',
#   'set hearts ablaze every city gift snog every skyline like kiss upon lips link',
#   'set hearts ablaze every city gift every skyline like kiss upon lip link',
#   'set snog hearts ablaze every city gift every skyline like kiss upon lips link'],
#  ['sky ablaze tonight los angeles im expecting ig fb filled sunset shots know peeps',
#   'sky ablaze tonight los angeles im ig fb filled sunset shots know peeps',
#   'sky ablaze tonight los angeles expecting ig fb im filled sunset shots know peeps',
#   'sky ablaze tonight los angeles im expecting ig fb filled sundown shots know peeps',
#   'sky ablaze tonight los angeles im expecting ig fb filled sunset shots aflare know peeps',
#   'sky ablaze tonight los angeles im expecting ig fb filled sunset shots know peep',
#   'flip sky ablaze tonight los angeles im expecting ig fb filled sunset shots know peeps'],
#  ['west burned thousands wildfires ablaze california alone link climate energy link',
#   'west burned thousands wildfires ablaze alone climate energy',
#   'west burned thousands wildfires ablaze climate alone link california energy link',
#   'west burned thousands wildfires ablaze ca alone link climate energy link',
#   'west aflare burned thousands wildfires ablaze california alone link climate energy link',
#   'west burned thousands wildfires afire california alone link climate energy link',
#   'westward west burned thousands wildfires ablaze california alone link climate energy link'],
#  ['revel wmv videos means mac farewell ablaze wmv en route dvd gtxrwm',
#   'revel videos mac farewell ablaze wmv en route dvd',
#   'revel wmv videos means mac farewell ablaze en route wmv dvd gtxrwm',
#   'revel wmv videos means mac farewell ablaze wmv en road dvd gtxrwm',
#   'revel videodisk wmv videos means mac farewell ablaze wmv en route dvd gtxrwm',
#   'revel wmv videos means macintosh farewell ablaze wmv en route dvd gtxrwm',
#   'revel wmv videos means mac farewell parting ablaze wmv en route dvd gtxrwm'],
#  ['progressive greetings month students would set pens ablaze torch publications link',
#   'progressive greetings month students would set torch link',
#   'progressive greetings set month students would pens ablaze torch publications link',
#   'progressive greetings calendar month students would set pens ablaze torch publications link',
#   'progressive great mullein greetings month students would set pens ablaze torch publications link',
#   'progressive greet month students would set pens ablaze torch publications link',
#   'progressive compose greetings month students would set pens ablaze torch publications link'],
#  ['rene ablaze amp jacinta secret k fallen skies edit mar link',
#   'rene ablaze amp jacinta k fallen skies edit mar link',
#   'rene ablaze amp jacinta mar k fallen skies edit secret link',
#   'rene ablaze amp jacinta secret k fallen ski edit mar link',
#   'rene ablaze amp jacinta aflare secret k fallen skies edit mar link',
#   'rene ablaze amp jacinta secret k fallen skies edit mar connection',
#   'rene strike ablaze amp jacinta secret k fallen skies edit mar link'],
#  ['navista steve fires something else california tinderbox clown setting hood ablaze news',
#   'navista steve fires something california tinderbox setting hood ablaze news',
#   'navista setting fires something else california tinderbox clown steve hood ablaze news',
#   'navista steve fires something else california tinderbox clown setting hood ablaze word',
#   'navista steve fires something else california tinderbox clown setting ca hood ablaze news',
#   'navista steve raise something else california tinderbox clown setting hood ablaze news',
#   'navista steve fires something ca else california tinderbox clown setting hood ablaze news'],
#  ['nowplaying rene ablaze amp ian buff magnitude link edm',
#   'nowplaying rene ablaze amp ian buff magnitude edm',
#   'nowplaying rene ablaze ian amp buff magnitude link edm',
#   'nowplaying rene ablaze amp ian buff magnitude connectedness edm',
#   'nowplaying rene ablaze amp ian aflare buff magnitude link edm',
#   'nowplaying rene ablaze amp ian buffet magnitude link edm',
#   'nowplaying rene ablaze linkup amp ian buff magnitude link edm'],
#  ['nxwestmidlands huge fire wholesale markets ablaze link',
#   'huge wholesale markets ablaze link',
#   'nxwestmidlands huge link wholesale markets ablaze fire',
#   'nxwestmidlands huge open fire wholesale markets ablaze link',
#   'nxwestmidlands huge fire wholesale linkup markets ablaze link',
#   'nxwestmidlands huge fire large quantities markets ablaze link',
#   'nxwestmidlands huge fire wholesale large quantities markets ablaze link'],
#  ['ablaze time talk go nt know make due work',
#   'time talk go nt know make due',
#   'ablaze time talk go nt know make due work',
#   'ablaze time talk go nt know take due work',
#   'ablaze time talk go nt know make due wreak work',
#   'ablaze time talk go nt know make referable work',
#   'ablaze time talk go nt know clip make due work'],
#  ['ca nt kids cuz got bicycle accident amp split testicles impossible kids michael father',
#   'ca nt kids cuz got accident amp testicles impossible michael father',
#   'ca kids cuz got bicycle accident amp split testicles nt impossible kids michael father',
#   'calcium nt kids cuz got bicycle accident amp split testicles impossible kids michael father',
#   'ca nt break kids cuz got bicycle accident amp split testicles impossible kids michael father',
#   'ca nt kids cuz got bicycle accident amp split testicles unsufferable kids michael father',
#   'ca nt kids cuz got bicycle accident amp split testicles impossible adenylic acid kids michael father'],
#  ['accident w nashvilletraffic traffic moving slower usual link',
#   'accident traffic moving usual link',
#   'accident w usual traffic moving slower nashvilletraffic link',
#   'stroke w nashvilletraffic traffic moving slower usual link',
#   'accident linkup w nashvilletraffic traffic moving slower usual link',
#   'accident w nashvilletraffic traffic move slower usual link',
#   'accident w nashvilletraffic linkup traffic moving slower usual link'],
#  ['accident center lane blocked santaclara us nb great america pkwy bayarea traffic link',
#   'accident center lane blocked santaclara us nb great america pkwy bayarea traffic link',
#   'accident center lane blocked santaclara bayarea us nb great america pkwy traffic link',
#   'accident center lane blocked santaclara us nb great america pkwy bayarea dealings link',
#   'accident center stymie lane blocked santaclara us nb great america pkwy bayarea traffic link',
#   'accident centre lane blocked santaclara us nb great america pkwy bayarea traffic link',
#   'accident center lane blocked usa santaclara us nb great america pkwy bayarea traffic link'],
#  ['link personalinjury accident summer read advice amp see solicitor help otleyhour',
#   'link personalinjury accident summer read amp solicitor otleyhour',
#   'link personalinjury amp summer read advice accident see solicitor help otleyhour',
#   'link personalinjury accident summer read advice amp see solicitor serve otleyhour',
#   'link personalinjury accident summer read advice amp see solicitor canvasser help otleyhour',
#   'link personalinjury accident summer show advice amp see solicitor help otleyhour',
#   'link personalinjury accident summer read advice amp see solicitor linkup help otleyhour'],
#  ['stlouis caraccidentlawyer speeding among top causes teen accidents link link car accident tee',
#   'stlouis speeding among top causes teen accidents car accident tee',
#   'stlouis causes speeding among top caraccidentlawyer teen accidents link link car accident tee',
#   'stlouis caraccidentlawyer speeding among top causes teen accidents link link car stroke tee',
#   'stlouis caraccidentlawyer speeding among top causes teen causa accidents link link car accident tee',
#   'stlouis caraccidentlawyer speeding among top causes teen accidents link link car chance event tee',
#   'stlouis caraccidentlawyer speeding among top causes teen accidents link link car accident hie tee'],
#  ['reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use link',
#   'reported motor accident herman rd near stephenson involving vehicle please',
#   'reported motor vehicle herman curry accident rd near stephenson involving overturned vehicle please use link',
#   'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use data link',
#   'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use penny pinching link',
#   'reported motor vehicle accident curry herman rd near stephenson involve overturned vehicle please use link',
#   'reported motor motive vehicle accident curry herman rd near stephenson involving overturned vehicle please use link'],
#  ['bigrigradio live accident awareness',
#   'bigrigradio live accident',
#   'accident live bigrigradio awareness',
#   'bigrigradio last accident awareness',
#   'bigrigradio consciousness live accident awareness',
#   'bigrigradio unrecorded accident awareness',
#   'bigrigradio live consciousness accident awareness'],
#  ['mile marker south mooresville iredell vehicle accident ramp closed pm',
#   'marker south mooresville iredell vehicle accident ramp closed pm',
#   'mile marker south ramp iredell vehicle accident mooresville closed pm',
#   'mile mark south mooresville iredell vehicle accident ramp closed pm',
#   'mile marker south mooresville iredell vehicle accident ramp close closed pm',
#   'mile marker south mooresville iredell vehicle accident rage closed pm',
#   'mile marker south close mooresville iredell vehicle accident ramp closed pm'],
#  ['rt sleepjunkies sleeping pills double risk car accident link',
#   'sleepjunkies pills risk car link',
#   'rt sleepjunkies sleeping pills car risk double accident link',
#   'rt sleepjunkies sleeping pills double take chances car accident link',
#   'rt sleepjunkies sleeping pills double risk peril car accident link',
#   'rt sleepjunkies sleeping pills double risk auto accident link',
#   'kip rt sleepjunkies sleeping pills double risk car accident link'],
#  ['accident knew gon happen link',
#   'accident knew gon happen link',
#   'accident knew link gon happen',
#   'accident knew gon happen connexion',
#   'accident linkup knew gon happen link',
#   'accident knew gon pass link',
#   'accident knew linkup gon happen link'],
#  ['traffic accident n cabrillo hwy magellan av mir',
#   'traffic accident n hwy magellan av mir',
#   'traffic accident n cabrillo hwy av magellan mir',
#   'traffic stroke n cabrillo hwy magellan av mir',
#   'traffic accident n cabrillo hwy magellan av fortuity mir',
#   'dealings accident n cabrillo hwy magellan av mir',
#   'traffic accident n cabrillo hwy magellan av dealings mir'],
#  ['mile marker south mooresville iredell vehicle accident congestion pm',
#   'mile marker south mooresville iredell vehicle congestion pm',
#   'mile marker south mooresville iredell vehicle accident congestion pm',
#   'mile marker south mooresville iredell vehicle accident congestion promethium',
#   'mile marker south mooresville iredell vehicle accident crowding congestion pm',
#   'mile marker south mooresville iredell vehicle accident crowding pm',
#   'mile fortuity marker south mooresville iredell vehicle accident congestion pm'],
#  ['pastor scene accident owner range rover',
#   'scene accident owner range rover',
#   'pastor scene accident owner range rover',
#   'minister religion scene accident owner range rover',
#   'pastor scene accident possessor owner range rover',
#   'pastor scene accident proprietor range rover',
#   'pastor scene accident owner vista range rover'],
#  ['mom nt get home fast wished mom accident truck spilt mayonnaise',
#   'get home fast mom accident truck spilt mayonnaise',
#   'mom nt get home fast wished mom accident truck spilt mayonnaise',
#   'mom nt get home fast wished mom accident motortruck spilt mayonnaise',
#   'mom nt get abode home fast wished mom accident truck spilt mayonnaise',
#   'mom nt get home fast wished mom accident truck spilt mayo',
#   'mom incur nt get home fast wished mom accident truck spilt mayonnaise'],
#  ['horrible car accident past sunday im finally able get around thank god',
#   'horrible car accident past sunday finally get around thank god',
#   'accident horrible car past sunday im finally able get around thank god',
#   'horrible cable car accident past sunday im finally able get around thank god',
#   'horrible car accident past sunday im finally able atrocious get around thank god',
#   'horrible car accident past dominicus im finally able get around thank god',
#   'horrible car atrocious accident past sunday im finally able get around thank god'],
#  ['wait see pissed donnie tell another accident',
#   'see pissed donnie tell another accident',
#   'wait see pissed donnie accident tell another',
#   'expect see pissed donnie tell another accident',
#   'wait see pissed donnie tell fortuity another accident',
#   'wait see pissed donnie say another accident',
#   'wait see pissed donnie tell fortuity another accident'],
#  ['truckcrash overturns fortworth interstate link click crash gt link',
#   'truckcrash fortworth interstate link crash link',
#   'truckcrash overturns fortworth interstate link click crash gt link',
#   'truckcrash overturns fortworth interstate highway link click crash gt link',
#   'truckcrash overturns fortworth interstate link click crash gt interstate highway link',
#   'truckcrash overturns fortworth interstate highway link click crash gt link',
#   'linkup truckcrash overturns fortworth interstate link click crash gt link'],
#  ['accident ashville us sb sr traffic link',
#   'ashville us sb sr traffic link',
#   'accident ashville us sb sr traffic link',
#   'accident ashville america sb sr traffic link',
#   'accident ashville us steradian sb sr traffic link',
#   'accident ashville us sb sr traffic yoke',
#   'accident ashville us sb sr traffic bs link'],
#  ['carolina accident motorcyclist dies crash car crossed median motorcycle rider traveling link',
#   'carolina accident motorcyclist crash car crossed median motorcycle rider traveling link',
#   'carolina accident crossed dies crash car motorcyclist median motorcycle rider traveling link',
#   'carolinas accident motorcyclist dies crash car crossed median motorcycle rider traveling link',
#   'carolina accident motorcyclist dies crash linkup car crossed median motorcycle rider traveling link',
#   'carolina accident motorcyclist dies crash car crossed median motorcycle passenger traveling link',
#   'carolina accident motorcyclist dies crash car crossed median motorcycle rider traveling travel link'],
#  ['fyi cad fyi accident property damage nhs piner rd horndale dr',
#   'fyi cad fyi property damage nhs piner rd horndale dr',
#   'fyi horndale fyi accident property damage nhs piner rd cad dr',
#   'fyi cad fyi fortuity property damage nhs piner rd horndale dr',
#   'scathe fyi cad fyi accident property damage nhs piner rd horndale dr',
#   'fyi cad fyi accident place damage nhs piner rd horndale dr',
#   'fyi cad fyi accident property damage fortuity nhs piner rd horndale dr'],
#  ['rt naayf first accident years turning onto chandanee magu near mma taxi rammed halfway turned everyone conf',
#   'years turning onto magu near mma taxi halfway turned conf',
#   'rt naayf first accident years turning onto chandanee magu near mma conf rammed halfway turned everyone taxi',
#   'rt naayf first accident years turning onto chandanee magu near mma hack rammed halfway turned everyone conf',
#   'rt naayf first accident years turning onto chandanee pound magu near mma taxi rammed halfway turned everyone conf',
#   'rt naayf first accident year turning onto chandanee magu near mma taxi rammed halfway turned everyone conf',
#   'rt naayf first accident years turning onto chandanee magu near mma taxi rammed sour halfway turned everyone conf'],
#  ['accident left lane blocked manchester rt nb eddy rd stop go traffic back nh delay mins traffic',
#   'lane manchester rt eddy rd stop traffic back nh delay mins traffic',
#   'accident left lane blocked manchester rt nb eddy rd stop go traffic back nh delay traffic mins',
#   'accident left lane blocked manchester rt nb eddy rd stop go traffic endorse nh delay mins traffic',
#   'accident left lane blocked manchester rt nb eddy rd stop go traffic back stymie nh delay mins traffic',
#   'accident left lane blocked manchester rt nb eddy rd stop depart traffic back nh delay mins traffic',
#   'accident left lane blocked manchester rt nb eddy rd stop go traffic back remaining nh delay mins traffic'],
#  ['accident property damage piner rd horndale dr',
#   'property piner rd horndale dr',
#   'accident property dr piner rd horndale damage',
#   'fortuity property damage piner rd horndale dr',
#   'fortuity accident property damage piner rd horndale dr',
#   'accident property impairment piner rd horndale dr',
#   'accident property damage piner rd scathe horndale dr'],
#  ['accident link',
#   'accident',
#   'accident link',
#   'chance event link',
#   'linkup accident link',
#   'chance event link',
#   'linkup accident link'],
#  ['fyi cad fyi accident property damage wpd th st',
#   'fyi cad fyi accident property damage wpd th st',
#   'wpd cad fyi accident property damage fyi th st',
#   'fyi cad fyi chance event property damage wpd th st',
#   'fyi cad scathe fyi accident property damage wpd th st',
#   'fyi cad fyi accident property price wpd th st',
#   'fyi cad fyi accident thursday property damage wpd th st'],
#  ['pm traffic accident injury willis foreman rd link',
#   'pm traffic accident injury willis foreman',
#   'pm traffic accident injury link foreman rd willis',
#   'pm dealings accident injury willis foreman rd link',
#   'pm traffic accident autopsy injury willis foreman rd link',
#   'pm traffic accident combat injury willis foreman rd link',
#   'pm autopsy traffic accident injury willis foreman rd link'],
#  ['aashiqui actress anu aggarwal near fatal accident link',
#   'aashiqui actress anu aggarwal near fatal link',
#   'link actress anu aggarwal near fatal accident aashiqui',
#   'aashiqui actress anu aggarwal near fatal fortuity link',
#   'aashiqui actress anu aggarwal near fatal accident fortuity link',
#   'aashiqui actress anu aggarwal near calamitous accident link',
#   'aashiqui actress anu aggarwal near fatal fateful accident link'],
#  ['suffield alberta accident link',
#   'suffield alberta accident',
#   'accident alberta suffield link',
#   'suffield alberta fortuity link',
#   'suffield alberta fortuity accident link',
#   'suffield alberta accident colligate',
#   'suffield fortuity alberta accident link'],
#  ['mile backup south accident blocking right lanes exit langtree rd consider nc nc nc alternate',
#   'mile backup south blocking right lanes exit langtree consider nc nc alternate',
#   'mile backup south accident blocking right lanes exit langtree rd nc nc nc consider alternate',
#   'mile backup south accident blocking right lanes exit langtree rd consider nc nc nc surrogate',
#   'north carolina mile backup south accident blocking right lanes exit langtree rd consider nc nc nc alternate',
#   'mile backup south stroke blocking right lanes exit langtree rd consider nc nc nc alternate',
#   'mile backup dixie south accident blocking right lanes exit langtree rd consider nc nc nc alternate'],
#  ['accident changed life help determine options financially support life care plans going treatment',
#   'accident changed life help options financially care plans going',
#   'accident changed life help determine treatment financially support life care plans going options',
#   'stroke changed life help determine options financially support life care plans going treatment',
#   'accident changed life help determine options financially support life care plans going tending treatment',
#   'stroke changed life help determine options financially support life care plans going treatment',
#   'accident changed life help discourse determine options financially support life care plans going treatment'],
#  ['breaking deadly motorcycle car accident happened hagerstown today details yourstate whag',
#   'breaking deadly motorcycle car accident happened hagerstown today yourstate',
#   'breaking deadly motorcycle accident happened hagerstown today car details yourstate whag',
#   'breaking deadly cycle car accident happened hagerstown today details yourstate whag',
#   'breaking deadly motorcycle car accident happened hagerstown today bike details yourstate whag',
#   'breaking deadly cycle car accident happened hagerstown today details yourstate whag',
#   'breaking deadly motorcycle car accident bike happened hagerstown today details yourstate whag'],
#  ['flowri marinading accident',
#   'flowri marinading accident',
#   'marinading flowri accident',
#   'flowri marinading stroke',
#   'flowri marinading fortuity accident',
#   'flowri marinate accident',
#   'flowri marinading fortuity accident'],
#  ['car even week got fucking car accident mfs ca nt fucking drive',
#   'car even fucking car accident mfs ca drive',
#   'ca even week got fucking car accident mfs car nt fucking drive',
#   'car even week got fucking car accident medium frequency ca nt fucking drive',
#   'car even week got fucking car accident national trust mfs ca nt fucking drive',
#   'car flush week got fucking car accident mfs ca nt fucking drive',
#   'car even week got eff fucking car accident mfs ca nt fucking drive'],
#  ['norwaymfa bahrain police previously died road accident killed explosion link',
#   'norwaymfa bahrain police previously road accident killed link',
#   'link bahrain police previously died road accident killed explosion norwaymfa',
#   'norwaymfa bahrain police previously died route accident killed explosion link',
#   'norwaymfa bahrain police previously died road accident constabulary killed explosion link',
#   'norwaymfa bahrain police previously died road accident killed explosion tie',
#   'norwaymfa constabulary bahrain police previously died road accident killed explosion link'],
#  ['still heard church leaders kenya coming forward comment accident issue disciplinary measures arrestpastornganga',
#   'still heard church leaders kenya coming forward comment accident issue disciplinary measures arrestpastornganga',
#   'still heard church leaders arrestpastornganga kenya coming forward comment accident issue disciplinary measures',
#   'still heard church leaders kenya coming forward comment accident come disciplinary measures arrestpastornganga',
#   'still heard church leaders kenya coming forward loss leader comment accident issue disciplinary measures arrestpastornganga',
#   'still heard church leaders kenya coming forward comment stroke issue disciplinary measures arrestpastornganga',
#   'still heard church leaders kenya coming forward forwards comment accident issue disciplinary measures arrestpastornganga'],
#  ['aftershock delo scuf ps live game cya',
#   'aftershock delo scuf ps live',
#   'aftershock live scuf ps delo game cya',
#   'aftershock delo scuf ps springy game cya',
#   'aftershock delo scuf ps live halt game cya',
#   'aftershock delo scuf ps exist game cya',
#   'aftershock delo scuf ps live halt game cya'],
#  ['man drive effort gets painful man win roger bannister',
#   'man effort gets painful man roger bannister',
#   'man drive effort painful man gets win roger bannister',
#   'man tug effort gets painful man win roger bannister',
#   'man drive balustrade effort gets painful man win roger bannister',
#   'man repulse effort gets painful man win roger bannister',
#   'man drive piece effort gets painful man win roger bannister'],
#  ['ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance ices link',
#   'ir icemoon aftershock link dnb edm ices link',
#   'ir icemoon dance link djicemoon dubstep trapmusic dnb edm aftershock ices link',
#   'ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance glass link',
#   'ir icemoon frappe aftershock link djicemoon dubstep trapmusic dnb edm dance ices link',
#   'atomic number icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance ices link',
#   'ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm frappe dance ices link'],
#  ['victory bargain basement prices dwight david eisenhower',
#   'victory basement prices dwight david eisenhower',
#   'victory bargain basement prices eisenhower david dwight',
#   'triumph bargain basement prices dwight david eisenhower',
#   'victory bargain basement prices dwight president eisenhower david eisenhower',
#   'victory bargain basement prices dwight david dwight eisenhower',
#   'victory bargain basement prices deal dwight david eisenhower'],
#  ['ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance ices link',
#   'ir icemoon aftershock link djicemoon dubstep dnb edm dance ices link',
#   'trapmusic icemoon aftershock link djicemoon dubstep ir dnb edm dance ices link',
#   'ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance frost link',
#   'ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance linkup ices link',
#   'ir icemoon aftershock nexus djicemoon dubstep trapmusic dnb edm dance ices nexus',
#   'ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance atomic number ices link'],
#  ['nobody remembers came second charles schulz',
#   'nobody remembers came second charles schulz',
#   'nobody remembers second came charles schulz',
#   'nobody remembers number second charles schulz',
#   'nobody remembers think back came second charles schulz',
#   'nobody remembers came secondment charles schulz',
#   'nobody cypher remembers came second charles schulz'],
#  ['aftershock delo im speaking someone using scuf xb people end getting ps also',
#   'aftershock delo im speaking someone using scuf xb people end getting',
#   'aftershock delo scuf speaking someone using im xb people end getting ps also',
#   'aftershock delo im oral presentation someone using scuf xb people end getting ps also',
#   'aftershock delo im speaking someone using scuf xb people end getting incur ps also',
#   'aftershock delo im verbalise someone using scuf xb people end getting ps also',
#   'aftershock delo im speaking someone using scuf apply xb people end getting ps also'],
#  ['harder conflict glorious triumph thomas paine',
#   'harder conflict triumph thomas paine',
#   'harder conflict glorious triumph thomas paine',
#   'harder conflict glorious triumph dylan marlais thomas paine',
#   'harder conflict exult glorious triumph thomas paine',
#   'harder conflict glorious triumph thomas tom paine',
#   'harder conflict glorious triumph thomas tom paine paine'],
#  ['growingupspoiled going clay pigeon shooting crying aftershock',
#   'growingupspoiled going pigeon shooting crying aftershock',
#   'growingupspoiled going clay shooting crying pigeon aftershock',
#   'growingupspoiled proceed clay pigeon shooting crying aftershock',
#   'growingupspoiled going shout clay pigeon shooting crying aftershock',
#   'growingupspoiled leaving clay pigeon shooting crying aftershock',
#   'growingupspoiled going clay pigeon shooting crying last aftershock'],
#  ['guess one actually wants free aftershock tc',
#   'one actually free aftershock',
#   'guess one actually wants free aftershock tc',
#   'guess one really wants free aftershock tc',
#   'guess one desire actually wants free aftershock tc',
#   'guess one actually wish free aftershock tc',
#   'guess guesswork one actually wants free aftershock tc'],
#  ['aftershock terrifying best roller coaster ever disclaimer',
#   'aftershock best coaster ever disclaimer',
#   'aftershock terrifying best roller coaster ever disclaimer',
#   'aftershock terrifying effect roller coaster ever disclaimer',
#   'aftershock tumbler pigeon terrifying best roller coaster ever disclaimer',
#   'aftershock terrifying best roller coaster always disclaimer',
#   'aftershock terrifying disavowal best roller coaster ever disclaimer'],
#  ['aftershock link',
#   'aftershock link',
#   'link aftershock',
#   'aftershock connection',
#   'aftershock linkup link',
#   'aftershock yoke',
#   'aftershock linkup link'],
#  ['ir icemoon aftershock link djicemoon dubstep trapmusic dnb edm dance ices link',
#   'ir icemoon link djicemoon dubstep trapmusic edm dance ices link',
#   'ir icemoon ices link djicemoon dubstep trapmusic dnb edm dance aftershock link',
# ...
#   'new ladies shoulder tote handbag faux leather hobo purse cross body bag purse womens link link'],
#  ['new summer long thin body bag hip word skirt blue link link',
#   'new summer long thin body bag skirt blue link',
#   'new summer long thin body bag hip word skirt blue link link',
#   'new summer long thin body bag hip word skirt puritanical link link',
#   'new summer long thin body bag purse hip word skirt blue link link',
#   'new summer long thin body bag hip word chick blue link link',
#   'new summer summertime long thin body bag hip word skirt blue link link'],
#  ['new ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link rt en',
#   'new ladies shoulder tote handbag faux leather hobo purse body bag womens link link rt en',
#   'new ladies shoulder tote handbag leather faux hobo purse cross body bag womens link link rt en',
#   'new ladies shoulder tote handbag faux leather hobo purse cross physical structure bag womens link link rt en',
#   'new ladies shoulder shoulder joint tote handbag faux leather hobo purse cross body bag womens link link rt en',
#   'new ladies shoulder tote handbag false leather hobo purse cross body bag womens link link rt en',
#   'new ladies shoulder tote handbag faux leather hobo tramp purse cross body bag womens link link rt en'],
#  ['louis vuitton monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie limited edition clutch cross link bag full read ebay link body',
#   'louis vuitton monogram sophie fix edition clutch cross body bag full read ebay link link',
#   'louis vuitton purse monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'joe louis vuitton monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie limited clasp edition clutch cross body bag full read ebay link link'],
#  ['new women handbag faux leather ladies shoulder tote cross body bag large satchel full link link',
#   'new women faux leather ladies tote cross body bag large full link link',
#   'new women link faux leather ladies shoulder tote cross body bag large satchel full handbag link',
#   'new women handbag faux leather ladies shoulder tote cross body bag big satchel full link link',
#   'new women handbag faux leather ladies shoulder tote cross body lady bag large satchel full link link',
#   'new women handbag faux leather ladies shoulder tote cross body base large satchel full link link',
#   'new women handbag faux leather ladies shoulder tote cross body bag large charwoman satchel full link link'],
#  ['new ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'ladies new shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross eubstance bag womens link link',
#   'new ladies shoulder fake tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse traverse body bag womens link link',
#   'new ladies shoulder tote handbag lady faux leather hobo purse cross body bag womens link link'],
#  ['one day heart gone get zipped body bag',
#   'day heart gone get body bag',
#   'one day heart gone get bag body zipped',
#   'one day heart plump get zipped body bag',
#   'purse one day heart gone get zipped body bag',
#   'one solar day heart gone get zipped body bag',
#   'one day heart gone get zipped last body bag'],
#  ['handbag fashion style link authentic louis vuitton pochette bosphore shoulder cross body bag link',
#   'handbag fashion style link louis bosphore body bag link',
#   'handbag fashion style link authentic louis pochette vuitton bosphore shoulder cross body bag link',
#   'bag fashion style link authentic louis vuitton pochette bosphore shoulder cross body bag link',
#   'expressive style handbag fashion style link authentic louis vuitton pochette bosphore shoulder cross body bag link',
#   'handbag fashion style link authentic louis vuitton pochette bosphore shoulder crisscross body bag link',
#   'handbag fashion style link authentic louis vuitton pochette bosphore shoulder cross forge body bag link'],
#  ['new ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies tote handbag faux leather hobo purse cross body link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross body link womens link bag',
#   'fresh ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux tug leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse hybridize body bag womens link link',
#   'new linkup ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link'],
#  ['handbag fashion style link vintage coach purse camera bag cross body bids link',
#   'handbag style link coach purse camera bag body bids',
#   'handbag fashion style link body coach purse camera bag cross vintage bids link',
#   'handbag fashion style link vintage coach purse camera traveling bag cross body bids link',
#   'linkup handbag fashion style link vintage coach purse camera bag cross body bids link',
#   'handbag fashion style link vintage coach purse camera bagful cross body bids link',
#   'handbag fashion linkup style link vintage coach purse camera bag cross body bids link'],
#  ['genuine leather man bag messenger fit ipad mini tablet case cross body air jp full rea link link',
#   'leather man bag messenger fit ipad mini tablet case cross body air full rea link link',
#   'link leather man bag messenger fit ipad mini tablet case cross body air jp full rea genuine link',
#   'genuine leather man bag messenger fit ipad miniskirt tablet case cross body air jp full rea link link',
#   'genuine leather man bag messenger fit ipad mini tablet case cross body air jp full rea purse link link',
#   'literal leather man bag messenger fit ipad mini tablet case cross body air jp full rea link link',
#   'genuine leather man bag messenger fit ipad mini tablet case cross body linkup air jp full rea link link'],
#  ['louis vuitton monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'vuitton monogram sophie limited edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie limited edition clutch cross body bag read full ebay link link',
#   'louis vuitton monogram sophie limit edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie linkup limited edition clutch cross body bag full read ebay link link',
#   'louis vuitton monogram sophie limited variation clutch cross body bag full read ebay link link',
#   'louis vuitton monogram clasp sophie limited edition clutch cross body bag full read ebay link link'],
#  ['new ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies tote leather hobo cross body bag womens link link',
#   'new ladies shoulder tote handbag faux hobo leather purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross consistency bag womens link link',
#   'new fake ladies shoulder tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies berm tote handbag faux leather hobo purse cross body bag womens link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross body bag newfangled womens link link'],
#  ['nuu fam fwt im leave body bag',
#   'fam fwt im leave body bag',
#   'im fam fwt nuu leave body bag',
#   'nuu fam fwt im leave consistency bag',
#   'parting nuu fam fwt im leave body bag',
#   'nuu fam fwt im leave body dish',
#   'nuu fam fwt im leave purse body bag'],
#  ['new ladies shoulder tote handbag faux leather hobo purse cross body bag womens full read link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross body bag full read link',
#   'new womens shoulder tote handbag faux leather hobo purse cross body bag ladies full read link link',
#   'new ladies shoulder tote handbag faux leather hobo purse cross body purse womens full read link link',
#   'new ladies shoulder tote handbag scan faux leather hobo purse cross body bag womens full read link link',
#   'new ladies shoulder tote handbag faux leather hobo wrinkle cross body bag womens full read link link',
#   'new ladies shoulder tote handbag faux leather hobo tramp purse cross body bag womens full read link link'],
#  ['rhee deliciousvomit im im saying lucky go home families put body bag',
#   'im im lucky go home families put body',
#   'rhee deliciousvomit go im im saying lucky home families put body bag',
#   'rhee deliciousvomit im im saying lucky go home families put torso bag',
#   'rhee deliciousvomit im im saying lucky go home families put body abode bag',
#   'rhee deliciousvomit im im saying favorable go home families put body bag',
#   'rhee deliciousvomit im im saying lucky go home organic structure families put body bag'],
#  ['matt bez oh im bagging body bangin im saying going get rose',
#   'matt bez oh im body bangin im saying going',
#   'matt bez im oh bagging body bangin im saying going get rose',
#   'matt bez buckeye state im bagging body bangin im saying going get rose',
#   'matt bez oh im bagging last body bangin im saying going get rose',
#   'matt bez oh im bag body bangin im saying going get rose',
#   'matt bez oh im bagging buckeye state body bangin im saying going get rose'],
#  ['ohmyloz rondarousey bagging body smoking hot',
#   'ohmyloz rondarousey bagging smoking hot',
#   'ohmyloz rondarousey bagging body hot smoking',
#   'ohmyloz rondarousey bag body smoking hot',
#   'ohmyloz rondarousey bag bagging body smoking hot',
#   'ohmyloz rondarousey bagging body fume hot',
#   'ohmyloz bag rondarousey bagging body smoking hot'],
#  ['drake really body bagging meek',
#   'really body bagging',
#   'drake really body bagging meek',
#   'drake really body sacking meek',
#   'drake sir francis drake really body bagging meek',
#   'drake really body bagging modest',
#   'drake really body bagging truth meek'],
#  ['fuckyeahcarey bornverified drake killing dude tea bagging dead body point',
#   'fuckyeahcarey drake killing dude tea bagging dead body point',
#   'fuckyeahcarey bornverified drake killing dude tea bagging dead body point',
#   'fuckyeahcarey bornverified drake killing dude tea pocket dead body point',
#   'fuckyeahcarey bornverified drake killing dude organic structure tea bagging dead body point',
#   'fuckyeahcarey bornverified drake kill dude tea bagging dead body point',
#   'fuckyeahcarey bornverified drake killing dude tea bagging dead body gallant point'],
#  ['meekmill w rec k league ball drake olympic level body bagging like career nothing trollingtilmeekdiss',
#   'meekmill rec k league ball drake olympic level body bagging like nothing trollingtilmeekdiss',
#   'w rec k league ball drake olympic level body bagging meekmill like career nothing trollingtilmeekdiss',
#   'meekmill w rec k league clod drake olympic level body bagging like career nothing trollingtilmeekdiss',
#   'meekmill w rec k league degree ball drake olympic level body bagging like career nothing trollingtilmeekdiss',
#   'meekmill w rec k league ball drake olympic dismantle body bagging like career nothing trollingtilmeekdiss',
#   'meekmill w rec k league ball drake olympic level body bagging like null career nothing trollingtilmeekdiss'],
#  ['idgaf tough canada north philly meek acting like bitch amp drake body bagging ass tracks',
#   'idgaf tough canada north philly meek acting like bitch amp drake body',
#   'idgaf tough canada north philly meek acting like bagging amp drake body bitch ass tracks',
#   'idgaf tough canada north philly meek acting like bitch amp drake body bagging ass traverse',
#   'playacting idgaf tough canada north philly meek acting like bitch amp drake body bagging ass tracks',
#   'idgaf tough canada north philly meek acting like bitch amp drake body bulge ass tracks',
#   'idgaf tough canada north philly meek acting like bitch amp drake body bagging bag ass tracks'],
#  ['yankees body bagging mfs',
#   'yankees body bagging mfs',
#   'yankees mfs bagging body',
#   'yankees personify bagging mfs',
#   'yankees body bagging medium frequency mfs',
#   'yankees body sacking mfs',
#   'medium frequency yankees body bagging mfs'],
#  ['broseidonrex dapurplesharpie skimmed twitter missed body bagging',
#   'broseidonrex dapurplesharpie skimmed twitter missed',
#   'dapurplesharpie broseidonrex skimmed twitter missed body bagging',
#   'broseidonrex dapurplesharpie skimmed twitter lose body bagging',
#   'broseidonrex dapurplesharpie skimmed twitter missed organic structure body bagging',
#   'broseidonrex dapurplesharpie skimmed twitter neglect body bagging',
#   'broseidonrex dapurplesharpie miss skimmed twitter missed body bagging'],
#  ['g link body bagging lyrically link',
#   'g link body bagging lyrically link',
#   'g link body bagging lyrically link',
#   'g link body bulge lyrically link',
#   'g link body bagging organic structure lyrically link',
#   'g link personify bagging lyrically link',
#   'g organic structure link body bagging lyrically link'],
#  ['bomairinge elutranscendent straight body bagging',
#   'bomairinge elutranscendent straight bagging',
#   'straight elutranscendent bomairinge body bagging',
#   'bomairinge elutranscendent straight trunk bagging',
#   'bomairinge organic structure elutranscendent straight body bagging',
#   'bomairinge elutranscendent straight organic structure bagging',
#   'bomairinge elutranscendent straight organic structure body bagging'],
#  ['body bagging bitches link',
#   'bagging bitches link',
#   'bagging body bitches link',
#   'body bagging squawk link',
#   'bag body bagging bitches link',
#   'body bulge bitches link',
#   'body linkup bagging bitches link'],
#  ['better feeling seeing stage day ones year friendships still body bagging mics together',
#   'feeling seeing stage day ones year still body bagging mics together',
#   'better feeling seeing friendships day ones year stage still body bagging mics together',
#   'effect feeling seeing stage day ones year friendships still body bagging mics together',
#   'better feeling seeing bag stage day ones year friendships still body bagging mics together',
#   'better feeling seeing degree day ones year friendships still body bagging mics together',
#   'better feeling seeing sidereal day stage day ones year friendships still body bagging mics together'],
#  ['mopheme bigstar johnson problem game body bagging niggas vuzuhustle',
#   'mopheme bigstar problem game body bagging niggas vuzuhustle',
#   'bagging bigstar johnson problem game body mopheme niggas vuzuhustle',
#   'mopheme bigstar johnson problem game body sacking niggas vuzuhustle',
#   'mopheme bigstar johnson nigra problem game body bagging niggas vuzuhustle',
#   'mopheme bigstar johnson trouble game body bagging niggas vuzuhustle',
#   'mopheme organic structure bigstar johnson problem game body bagging niggas vuzuhustle'],
#  ['body bagging today got post score link',
#   'body bagging today got post score link',
#   'body bagging got today post score link',
#   'body bagging today got station score link',
#   'body bagging today got post nock score link',
#   'torso bagging today got post score link',
#   'body bagging today got nowadays post score link'],
#  ['editaxohaze let bagging body begin lol ai nt cuffed yet nt bad',
#   'editaxohaze let body begin lol ai cuffed nt bad',
#   'bad let bagging body begin lol ai nt cuffed yet nt editaxohaze',
#   'editaxohaze let bagging body begin lol army intelligence nt cuffed yet nt bad',
#   'editaxohaze let bagging body begin lol ai nt commence cuffed yet nt bad',
#   'editaxohaze let bagging body get lol ai nt cuffed yet nt bad',
#   'editaxohaze let national trust bagging body begin lol ai nt cuffed yet nt bad'],
#  ...]

# %% [markdown]
# # Split data into train, validation and test sets

# %% [markdown]
# Training Dataset:
# The sample of data used to fit the model.
#
# Validation Dataset:
# The sample of data used to provide an unbiased evaluation of a model fit on the training dataset while tuning model hyperparameters. The evaluation becomes more biased as skill on the validation dataset is incorporated into the model configuration.
#
# Test Dataset:
# The sample of data used to provide an unbiased evaluation of a final model fit on the training dataset.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25,
                                                    random_state=42)

X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=0.25,
                                                    random_state=42)

X_train = [item for sublist in X_train for item in sublist]
Y_train = [item for sublist in Y_train for item in sublist]

X_validation = [item for sublist in X_validation for item in sublist]
Y_validation = [item for sublist in Y_validation for item in sublist]

X_test = [item for sublist in X_test for item in sublist]
Y_test = [item for sublist in Y_test for item in sublist]

print("Train: {train_size}\nValidation: {validation_size}\nTest: {test_size}\n".format(train_size=len(X_train), validation_size=len(X_validation), test_size=len(X_test)))
# Out:
# Train: 29943
# Validation: 9988
# Test: 13312

# %%
X_train[0]
# Out:
# 'xgn infinity ronin carbon hahah mutual host preset bal nades radar demolish'

# %%
# tokenizer
tokenizer = Tokenizer(num_words=max_words)  

# Updates internal vocabulary based on a list of texts. 
# This method creates the vocabulary index based on word frequency. 
tokenizer.fit_on_texts(X_train)

# Transforms each row from texts to a sequence of integers. 
# So it basically takes each word in the text and replaces it 
# with its corresponding integer value from the
X_train = tokenizer.texts_to_sequences(X_train)
X_validation = tokenizer.texts_to_sequences(X_validation)
X_test = tokenizer.texts_to_sequences(X_test)


# Pad sequences
X_train = pad_sequences(X_train, maxlen=max_sequence_length, dtype='int32', value=0)
X_validation = pad_sequences(X_validation, maxlen=max_sequence_length, dtype='int32', value=0)
X_test = pad_sequences(X_test, maxlen=max_sequence_length, dtype='int32', value=0)

word_index = tokenizer.word_index

X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_validation = np.array(X_validation)
Y_validation = np.array(Y_validation)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %% [markdown]
# # LSTM Model

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.regularizers import l2

l2_reg = l2(0.001)

def model_fn():
    model = Sequential()

    model.add(Embedding(max_words, embedding_size, input_length=max_sequence_length, embeddings_regularizer=l2_reg))
    
    model.add(SpatialDropout1D(0.5))
    
    model.add(LSTM(32, dropout=0.5, recurrent_dropout=0.5, kernel_regularizer=l2_reg, recurrent_regularizer=l2_reg, bias_regularizer=l2_reg))
    
    model.add(Dropout(0.5))
    
    model.add(Dense(512, activation='relu'))

    model.add(Dense(1, activation='sigmoid'))
    optimizer = RMSprop(lr=0.0001, rho=0.9, epsilon=1e-08, decay=0.0)
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

    print(model.summary())

    return model

# %% [markdown]
# # Training

# %%
import os
import numpy as np
import pickle

# epochs
epochs = 10

# number of samples to use for each gradient update
batch_size = 128

# saving tokenizer
with open(tokenizer_file, 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

model = model_fn()

# loadin saved model
if os.path.exists(model_file):
    model.load_weights(model_file)

history = model.fit(X_train, Y_train,
          validation_data=(X_validation, Y_validation),
          epochs=epochs,
          batch_size=batch_size,
          shuffle=True,
          verbose=1)

# saving model
model.save_weights(model_file)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 30, 30)            90000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 30, 30)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8064
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               16896
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 115,473
# Trainable params: 115,473
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 29943 samples, validate on 9988 samples
# Epoch 1/10
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 29943/29943 [==============================] - 6s 213us/sample - loss: 0.6044 - accuracy: 0.7162 - val_loss: 0.5769 - val_accuracy: 0.7384
# Epoch 2/10
# 29943/29943 [==============================] - 5s 155us/sample - loss: 0.5429 - accuracy: 0.7592 - val_loss: 0.5430 - val_accuracy: 0.7597
# Epoch 3/10
# 29943/29943 [==============================] - 4s 146us/sample - loss: 0.5063 - accuracy: 0.7831 - val_loss: 0.5279 - val_accuracy: 0.7673
# Epoch 4/10
# 29943/29943 [==============================] - 4s 146us/sample - loss: 0.4821 - accuracy: 0.8018 - val_loss: 0.5110 - val_accuracy: 0.7770
# Epoch 5/10
# 29943/29943 [==============================] - 4s 147us/sample - loss: 0.4646 - accuracy: 0.8116 - val_loss: 0.5071 - val_accuracy: 0.7776
# Epoch 6/10
# 29943/29943 [==============================] - 5s 151us/sample - loss: 0.4514 - accuracy: 0.8210 - val_loss: 0.4991 - val_accuracy: 0.7881
# Epoch 7/10
# 29943/29943 [==============================] - 5s 154us/sample - loss: 0.4373 - accuracy: 0.8271 - val_loss: 0.4948 - val_accuracy: 0.7932
# Epoch 8/10
# 29943/29943 [==============================] - 5s 153us/sample - loss: 0.4296 - accuracy: 0.8327 - val_loss: 0.4896 - val_accuracy: 0.7991
# Epoch 9/10
# 29943/29943 [==============================] - 5s 154us/sample - loss: 0.4216 - accuracy: 0.8390 - val_loss: 0.4933 - val_accuracy: 0.7912
# Epoch 10/10
# 29943/29943 [==============================] - 5s 155us/sample - loss: 0.4181 - accuracy: 0.8396 - val_loss: 0.4898 - val_accuracy: 0.7981

# %% [markdown]
# # Show loss and accuracy

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.show()

# %%
# evaluate model
scores = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
print("Acc: %.2f%%" % (scores[1] * 100))
# Out:
# Acc: 78.20%

# %% [markdown]
# # create submission

# %%
test = pd.read_csv('test.csv')

# Clear text
test['text'] = test['text'].apply(lambda x: clean_str(x))

# Remove stop words
test['text'] = test['text'].apply(lambda x: " ".join(remove_stopwords(x.split(" "))))

# Get text
test_X = list(test["text"])

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(test_X)

# Pad sequences
sequences = pad_sequences(sequences,
                             maxlen=max_sequence_length,
                             dtype='int32',
                             value=0)

# Predict sequences
predicted = model.predict(sequences)

binary_predicted = np.array(predicted) >= 0.5
targets = binary_predicted.astype(int).reshape((len(binary_predicted)))
my_submission = pd.DataFrame({'id': test.id, 'target': targets})
my_submission.to_csv('submission.csv', index=False)

print("Submission file created!")
# Out:
# Submission file created!
